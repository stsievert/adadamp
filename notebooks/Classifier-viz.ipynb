# %% [markdown]
# # Training data visualization

# %% [markdown]
# This notebook uses this Matplotlib plotting API: https://matplotlib.org/3.1.1/api/axes_api.html

# %%
import json
import matplotlib.pyplot as plt
import pandas as pd

# %%
with open('./stats.json', 'r') as fp:
    data = json.load(fp)
    
hist = data.pop("history")
params = data.pop("params")
assert data == {}
df = pd.DataFrame(hist)

# %%
df.columns
# Out:
# Index(['epoch', 'n_updates', 'n_data', 'score__calls', 'partial_fit__calls',
#        'partial_fit__time', 'partial_fit__batch_size', 'score__acc',
#        'score__loss', 'score__time'],
#       dtype='object')

# %% [markdown]
# Matplotlib plotting with `subplots`: https://matplotlib.org/3.1.1/api/axes_api.html

# %%
fig, ax = plt.subplots()
df.plot(x="epoch", y="score__loss", ax=ax)
ax.set_title("Progress")
ax.set_ylabel("Test loss")
ax.grid(alpha=0.6)

# %%
fig, ax = plt.subplots()
df.plot(x="epoch", y="score__acc", ax=ax)
ax.set_title("Progress")
ax.set_ylabel("Test loss")
ax.grid(alpha=0.6)

# %%
ax = df["partial_fit__time"].plot.hist()
ax.set_xlabel("Time for one epoch (s)")
# Out:
# Text(0.5, 0, 'Time for one epoch (s)')

# %%
ax = df["score__time"].plot.hist()
